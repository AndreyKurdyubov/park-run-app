# %%
import pandas as pd

# %%
runners_df = pd.read_csv('runners.csv')
runners_df.head()
# Out:
#    Unnamed: 0                       run  run_number  \
# 0           0  Петергоф Александрийский       125.0
# 1           1  Петергоф Александрийский       125.0
# 2           2  Петергоф Александрийский       125.0
# 3           3  Петергоф Александрийский       125.0
# 4           4  Петергоф Александрийский       125.0
#
#                      run_date  \
# 0  2024-10-05 00:00:00.000000
# 1  2024-10-05 00:00:00.000000
# 2  2024-10-05 00:00:00.000000
# 3  2024-10-05 00:00:00.000000
# 4  2024-10-05 00:00:00.000000
#
#                                             run_link  finisher  volunteer  \
# 0  https://5verst.ru/petergofaleksandriysky/resul...       122         26
# 1  https://5verst.ru/petergofaleksandriysky/resul...       122         26
# 2  https://5verst.ru/petergofaleksandriysky/resul...       122         26
# 3  https://5verst.ru/petergofaleksandriysky/resul...       122         26
# 4  https://5verst.ru/petergofaleksandriysky/resul...       122         26
#
# ...
